# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('Housing_Price.csv')
data
# Out:
#         price  area  bedrooms  bathrooms  stories  parking
# 0    13300000  7420         4          2        3        2
# 1    12250000  8960         4          4        4        3
# 2    12250000  9960         3          2        2        2
# 3    12215000  7500         4          2        2        3
# 4    11410000  7420         4          1        2        2
# ..        ...   ...       ...        ...      ...      ...
# 540   1820000  3000         2          1        1        2
# 541   1767150  2400         3          1        1        0
# 542   1750000  3620         2          1        1        0
# 543   1750000  2910         3          1        1        0
# 544   1750000  3850         3          1        2        0
#
# [545 rows x 6 columns]

# %%
# %matplotlib inline
from matplotlib import rcParams
rcParams['figure.figsize'] = 15,7
plt.scatter(data['area'],data['price'],color = 'green', marker = '+')
plt.grid(True)

# %%
rcParams['figure.figsize'] = 10,5
plt.scatter(data['bedrooms'],data['price'],color = 'green', marker = '+')
plt.grid(True)

# %%
plt.scatter(data['bathrooms'],data['price'],color = 'green', marker = '+')
rcParams['figure.figsize'] = 10,5
plt.grid(True)

# %%
plt.scatter(data['stories'],data['price'],color = 'green', marker = '+')
rcParams['figure.figsize'] = 10,5
plt.grid(True)

# %%
plt.scatter(data['parking'],data['price'],color = 'green', marker = '+')
rcParams['figure.figsize'] = 10,5
plt.grid(True)

# %%
x = data[['area','bedrooms','bathrooms','stories','parking']]
y = data[['price']]
x
# Out:
#      area  bedrooms  bathrooms  stories  parking
# 0    7420         4          2        3        2
# 1    8960         4          4        4        3
# 2    9960         3          2        2        2
# 3    7500         4          2        2        3
# 4    7420         4          1        2        2
# ..    ...       ...        ...      ...      ...
# 540  3000         2          1        1        2
# 541  2400         3          1        1        0
# 542  3620         2          1        1        0
# 543  2910         3          1        1        0
# 544  3850         3          1        2        0
#
# [545 rows x 5 columns]

# %%
y
# Out:
#         price
# 0    13300000
# 1    12250000
# 2    12250000
# 3    12215000
# 4    11410000
# ..        ...
# 540   1820000
# 541   1767150
# 542   1750000
# 543   1750000
# 544   1750000
#
# [545 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test =train_test_split(x,y, test_size = 0.2)

# %%
len(x_train)
# Out:
# 436

# %%
len(x_test)
# Out:
# 109

# %%
436+109 # 80% traing and 20% testing from the entire data set
# Out:
# 545

# %%
x_train # the model randomly coosing the data not from the top 80%
# Out:
#      area  bedrooms  bathrooms  stories  parking
# 49   7440         3          2        1        0
# 385  3640         2          1        1        0
# 473  8050         2          1        1        0
# 295  2325         3          1        2        0
# 430  2500         2          1        1        0
# ..    ...       ...        ...      ...      ...
# 162  6600         4          2        2        0
# 140  5800         3          2        4        0
# 132  5200         3          1        3        0
# 213  4995         4          2        1        0
# 37   9000         4          2        4        2
#
# [436 rows x 5 columns]

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
model.score(x_test, y_test)
# Out:
# 0.6097283095206567

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
model_2 = DecisionTreeClassifier()

# %%
model_2.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
model_2.score(x_test, y_test)
# Out:
# 0.009174311926605505

# %%
import pickle
with open ('Housing_pickle', 'wb') as f:
    pickle.dump(model,f)

# %%
with open ('Housing_pickle', 'rb') as f:
    mp = pickle.load(f)
